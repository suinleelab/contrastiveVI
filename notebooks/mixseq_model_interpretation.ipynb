# %%
import os
import pandas as pd
import numpy as np
import scanpy as sc
import gseapy as gp
import seaborn as sns

from tqdm import tqdm
from scripts import constants

# %%
dataset = "mcfarland_2020"

# %%
adata = sc.read_h5ad(
    os.path.join(
        constants.DEFAULT_DATA_PATH,
        f"{dataset}/preprocessed/adata_top_2000_genes.h5ad",
    )
)
# Out:
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.

# %%
target_indices = np.where(adata.obs["condition"] != "DMSO")[0]

# %%
genes = pd.read_table(
    os.path.join(
        "/projects/leelab/data/single-cell/mcfarland_2020",
        "idasanutlin/Idasanutlin_24hr_expt1",
        "genes.tsv",
    ),
    header=None,
)
genes = genes.rename(columns={0: "ensembl_id", 1: "gene_symbol"})
genes = genes[genes["ensembl_id"].isin(adata.var.index)]

# %%
"TP53" in genes["gene_symbol"]
# Out:
# False

# %%
seeds = [123, 42, 789, 46, 999]
latent_size = 10
result_list = []

for seed in tqdm(seeds):
    background_expr = np.load(
        os.path.join(
            constants.DEFAULT_RESULTS_PATH,
            f"{dataset}/contrastiveVI/latent_{latent_size}/{seed}",
            "background_normalized_expression.npy",
        ),
    )
    salient_expr = np.load(
        os.path.join(
            constants.DEFAULT_RESULTS_PATH,
            f"{dataset}/contrastiveVI/latent_{latent_size}/{seed}",
            "salient_normalized_expression.npy",
        ),
    )
    background_expr = background_expr[target_indices, :]
    salient_expr = salient_expr[target_indices, :]
    
    expr_mag_change = np.abs(salient_expr - background_expr)
    expr_mag_logfc = np.abs(np.log2(salient_expr / background_expr))
    
    results = genes.copy()
    results["mag_change_mean"] = np.mean(expr_mag_change, axis=0)
    results["mag_change_median"] = np.median(expr_mag_change, axis=0)
    results["mag_logfc_mean"] = np.mean(expr_mag_logfc, axis=0)
    results["mag_logfc_median"] = np.median(expr_mag_logfc, axis=0)
    results["seed"] = seed
    result_list.append(results)

results = pd.concat(result_list)
results = results.drop(columns=["ensembl_id"])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  2.85it/s]

# %%
result_means = results.groupby("gene_symbol", as_index=False).mean().drop(columns=["seed"])

# %%
metric_list = [
    "mag_change_mean",
    "mag_change_median",
    "mag_logfc_mean",
    "mag_logfc_median",
]

# %%
sns.pairplot(result_means[metric_list])

# %%
enr_result_dict = {}
top_gene_dict = {}
top_k = 100
for metric in metric_list:
    print(metric)
    sorted_genes = result_means.sort_values(by=metric, ascending=False)
    top_genes = sorted_genes.head(n=top_k)["gene_symbol"].tolist()
    enr = gp.enrichr(
        gene_list=top_genes,
        gene_sets="KEGG_2016",
        organism="human",
        cutoff=0.1,
    )
    enr_results = enr.results
    enr_results = enr_results[enr_results["Adjusted P-value"] < 0.1]
    enr_results = enr_results.sort_values(by="Adjusted P-value")
    
    enr_result_dict[metric] = enr_results
    top_gene_dict[metric] = top_genes
# Out:
# mag_change_mean
# mag_change_median
# 30   13.517007       60.795508
# 31    6.380155       27.488267
# 32    6.314061       27.033723
# 33    3.534247       14.454454
# 34    4.146044       16.504186
# 35    9.424300       36.269737
# 36    5.320932       20.455914
#
#                                                Genes
# 0                LDHB;LDHA;TPI1;PKM;ENO1;ALDOA;GAPDH
# 1            CDKN1A;TP53I3;CCND1;GADD45A;IGFBP3;MDM2
# 2                            MT2A;FTH1;MT1X;MT1E;FTL
# 3            CDKN1A;HSP90AA1;CCND1;GSTP1;MDM2;CTNNB1
# 4                    TUBA1C;TUBA1B;KRT18;TUBB;CTNNB1
# 5              LDHA;CDKN1A;EIF4EBP1;ENO1;ALDOA;GAPDH
# 6                          TPI1;PKM;ENO1;ALDOA;GAPDH
# 7    RANBP1;CDKN1A;PKM;CCND1;HIST1H2BK;MDM2;HIST1H4C
# 8                          TPI1;PKM;ENO1;ALDOA;GAPDH
# 9                            CDKN1A;CCND1;MDM2;CALM2
# 10  RANBP1;CDKN1A;CCND1;PTTG1;CTNNB1;SLC25A5;SLC25A6
# 11                   CDKN1A;CCND1;PTTG1;GADD45A;MDM2
# 12                 CDKN1A;CCND1;CAV1;MDM2;FN1;CTNNB1
# 13                  RPS4X;RPL23;RPS27L;RPL22L1;RPL19
# 14                                     LDHB;LDHA;PKM
# 15                    TUBA1C;TUBA1B;TUBB;SEC61G;CYBA
# 16                                 CDKN1A;CCND1;MDM2
# 17                               LDHB;LDHA;PKM;CALM2
# 18                                EEF1A1;HSPA8;CXCL1
# 19                       HSPA8;CDKN1A;MDM2;HSPB1;VIM
# 20       HSP90AA1;CDKN1A;CCND1;GSTP1;MDM2;FN1;CTNNB1
# 21                         CDKN1A;CCND1;GADD45A;MDM2
# 22                                 CDKN1A;CCND1;MDM2
# 23                                 CDKN1A;CCND1;MDM2
# 24                                   CAV1;FN1;CTNNB1
# 25           HSP90AA1;CDKN1A;CCND1;MDM2;EIF4EBP1;FN1
# 26                                      CCND1;CTNNB1
# 27                                TUBA1C;TUBA1B;TUBB
# 28                       HSPA8;HSP90AA1;SEC61G;CRYAB
# 29                                         LDHB;LDHA
# 30                                        TPI1;ALDOA
# 31                              HSPA8;HSP90AA1;CALM2
# 32                                   FN1;HSPB1;CXCL1
# 33                        CDKN1A;CCND1;TPM1;MDM2;VIM
# 34                             CCND1;CAV1;FN1;CTNNB1
# 35                                         LDHB;LDHA
# 36                                 CCND1;MDM2;CTNNB1

# %%
enr_result_dict["mag_logfc_median"]
# Out:
#     Gene_set                                      Term Overlap   P-value  \
# 0  KEGG_2016  Retinol metabolism Homo sapiens hsa00830    4/65  0.000315
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.027113            0                     0    13.55123
#
#    Combined Score                          Genes
# 0      109.251427  CYP26A1;UGT2B11;DHRS9;ALDH1A1
