# %%
import os
import torch
import pandas as pd
import numpy as np
import scanpy as sc
import gseapy as gp
import seaborn as sns

from tqdm import tqdm
from functools import partial
from sklearn.cluster import KMeans
from scvi.model.base._utils import _de_core
from scvi.model._utils import _get_var_names_from_setup_anndata,  scrna_raw_counts_properties
from scripts import constants
from contrastive_vi.model.contrastive_vi import ContrastiveVIModel
from scvi.model import SCVI

from anndata import AnnData
from typing import Dict, Iterable, Optional, Sequence, Union
from scvi._compat import Literal

Number = Union[int, float]
# Out:
# Global seed set to 0
# During startup - Warning messages:
# 1: package ‘methods’ was built under R version 3.6.1
# 2: package ‘datasets’ was built under R version 3.6.1
# 3: package ‘utils’ was built under R version 3.6.1
# 4: package ‘grDevices’ was built under R version 3.6.1
# 5: package ‘graphics’ was built under R version 3.6.1
# 6: package ‘stats’ was built under R version 3.6.1

# %%
dataset = "zheng_2017"

split_key = constants.DATASET_SPLIT_LOOKUP[dataset]["split_key"]
background_value = constants.DATASET_SPLIT_LOOKUP[dataset]["background_value"]

# %%
adata = sc.read_h5ad(
    os.path.join(
        constants.DEFAULT_DATA_PATH,
        f"{dataset}/preprocessed/adata_top_2000_genes.h5ad",
    )
)
SCVI.setup_anndata(adata, layer="count")
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["count"]
# INFO     Successfully registered anndata object containing 16856 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %%
target_indices = np.where(adata.obs[split_key] != background_value)[0]
target_adata = adata[target_indices]

# %%
genes = pd.read_table(
    os.path.join(
        constants.DEFAULT_DATA_PATH,
        dataset,
        "aml027_post_transplant_filtered_gene_bc_matrices",
        "filtered_matrices_mex/hg19",
        "genes.tsv",
    ),
    header=None,
)
genes = genes.rename(columns={0: "ensembl_id", 1: "gene_symbol"})
genes = genes[genes["ensembl_id"].isin(adata.var.index)]

# %%
seeds = [123, 42, 789, 46, 999]
latent_size = 10
model_list = [
    torch.load(
        os.path.join(
            constants.DEFAULT_RESULTS_PATH,
            f"{dataset}/scVI/latent_{latent_size}/{seed}/model.ckpt",
        ),
        map_location="cpu",
    )
    for seed in tqdm(seeds)
]
latent_rep_list = [
    np.load(
        os.path.join(
            constants.DEFAULT_RESULTS_PATH,
            f"{dataset}/scVI/latent_{latent_size}/{seed}/latent_representations.npy",
        ),
    )
    for seed in tqdm(seeds)
]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:51<00:00, 10.35s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 17.45it/s]

# %%
result_list = []
for seed_index, seed in enumerate(seeds):
    model = model_list[seed_index]
    latent_rep = latent_rep_list[seed_index]
    
    target_adata = model._validate_anndata(target_adata.copy())
    col_names = _get_var_names_from_setup_anndata(target_adata)
    
    latent_clusters = KMeans(n_clusters=2, random_state=123).fit(latent_rep).labels_
    target_adata.obs[f"cluster_{seeds[seed_index]}"] = latent_clusters.astype(str)

    def get_normalized_expression(
        adata: Optional[AnnData] = None,
        indices: Optional[Sequence[int]] = None,
        transform_batch: Optional[Sequence[Union[Number, str]]] = None,
        gene_list: Optional[Sequence[str]] = None,
        library_size: Union[float, Literal["latent"]] = 1,
        n_samples: int = 1,
        n_samples_overall: int = None,
        batch_size: Optional[int] = None,
        return_mean: bool = True,
        return_numpy: Optional[bool] = None,
    ):
        return model.get_normalized_expression(
            adata=adata,
            indices=indices,
            transform_batch=transform_batch,
            gene_list=gene_list,
            library_size=library_size,
            n_samples=n_samples,
            n_samples_overall=n_samples_overall,
            batch_size=batch_size,
            return_mean=return_mean,
            return_numpy=return_numpy,
        )
    
    model_fn = partial(
        get_normalized_expression,
        return_numpy=True,
        n_samples=100,
        batch_size=128,
    )
    result = _de_core(
        target_adata,
        model_fn,
        groupby=f"cluster_{seeds[seed_index]}",
        group1="0",
        group2="1",
        idx1=None,
        idx2=None,
        all_stats=True,
        all_stats_fn=scrna_raw_counts_properties,
        col_names=col_names,
        mode="change",
        batchid1=None,
        batchid2=None,
        delta=0.25,
        batch_correction=False,
        fdr=0.05,
        silent=False,
    )
    result.reset_index()
    result["ensembl_id"] = result.index
    result = result.merge(genes, on="ensembl_id")
    result_list.append(result)
# Out:
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:24<00:00, 24.95s/it]
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:24<00:00, 24.58s/it]
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:30<00:00, 30.49s/it]
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:31<00:00, 31.33s/it]
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:26<00:00, 26.15s/it]

# %%
for seed_index, seed in enumerate(seeds):
    result_list[seed_index]["seed"] = seed

# %%
all_result = pd.concat(result_list)

# %%
all_result_mean = (
    all_result.groupby("gene_symbol", as_index=False)
    .mean()
    .sort_values(by="proba_de", ascending=False)
)

# %%
top_genes = all_result_mean[all_result_mean["proba_de"] > 0.95]["gene_symbol"].tolist()

# %%
enr = gp.enrichr(
    gene_list=top_genes,
    gene_sets="KEGG_2016",
    organism="human",
    cutoff=0.05,
)

# %%
enr_results = enr.results
enr_results = enr_results[enr_results["Adjusted P-value"] < 0.1]

# %%
cols = ["Gene_set", "Term", "Adjusted P-value", "Overlap", "Genes"]
enr_results[cols]
# Out:
#      Gene_set                                               Term  \
# 0   KEGG_2016                       Asthma Homo sapiens hsa05310
# 1   KEGG_2016   Hematopoietic cell lineage Homo sapiens hsa04640
# 2   KEGG_2016     Type I diabetes mellitus Homo sapiens hsa04940
# 3   KEGG_2016    Graft-versus-host disease Homo sapiens hsa05332
# 4   KEGG_2016                Leishmaniasis Homo sapiens hsa05140
# 5   KEGG_2016          Allograft rejection Homo sapiens hsa05330
# 6   KEGG_2016  Antigen processing and presentation Homo sapie...
# 7   KEGG_2016         Rheumatoid arthritis Homo sapiens hsa05323
# 8   KEGG_2016                  Influenza A Homo sapiens hsa05164
# 9   KEGG_2016  Staphylococcus aureus infection Homo sapiens h...
# 10  KEGG_2016  Cell adhesion molecules (CAMs) Homo sapiens hs...
# 11  KEGG_2016  Inflammatory bowel disease (IBD) Homo sapiens ...
# 14      6.807289e-05  20/135
# 15      6.807289e-05   12/53
# 16      1.244027e-04  18/118
# 17      2.353991e-04  23/185
# 18      3.706022e-04  22/178
# 19      1.102159e-03  18/140
# 20      3.541612e-03  18/154
# 21      3.682808e-03  14/104
# 22      4.111458e-03    9/49
# 23      5.500408e-03   11/73
# 24      5.946805e-03   11/74
# 25      9.367948e-03  24/258
# 26      9.367948e-03   10/67
# 27      1.071297e-02  20/202
# 28      1.071297e-02   12/93
# 29      1.172911e-02    7/37
# 30      1.705017e-02    9/62
# 31      1.705017e-02    9/62
# 32      1.711364e-02    7/40
# 33      2.488623e-02  14/132
# 34      2.677634e-02    8/55
# 35      3.564753e-02  12/110
# 36      4.589368e-02  11/100
# 37      4.677563e-02    8/61
# 38      5.070138e-02    9/75
# 39      5.070138e-02    7/50
# 40      5.524269e-02  11/104
# 41      6.042595e-02  13/135
# 42      6.042595e-02  11/106
# 43      7.646849e-02    8/68
# 44      8.597481e-02    5/32
# 45      8.838300e-02    7/57
# 46      9.868894e-02    9/86
#
#                                                 Genes
# 0   IL10;HLA-DRB5;FCER1G;PRG2;RNASE3;TNF;HLA-DMA;H...
# 1   GYPA;HLA-DRB5;CSF1;DNTT;GP1BA;TNF;CD3D;CD2;FCE...
# 2   HLA-DRB5;GAD1;ICA1;GZMB;TNF;HLA-DMA;HLA-DMB;IL...
# 3   HLA-DRB5;GZMB;TNF;HLA-DMA;HLA-DMB;IL1B;HLA-DPB...
# 4   IL10;JUN;MARCKSL1;HLA-DRB5;NCF2;PTGS2;TNF;NFKB...
# 5   IL10;HLA-DRB5;GZMB;TNF;HLA-DMA;HLA-DMB;HLA-DPB...
# 6   CD74;HLA-DRB5;HSPA6;IFI30;TNF;CTSS;HLA-DMA;HLA...
# 7   JUN;HLA-DRB5;CSF1;CCL3L1;TNF;HLA-DMA;HLA-DMB;I...
# 8   TNF;ACTG1;PIK3R5;CASP9;SOCS3;HLA-DMA;HLA-DMB;C...
# 9   IL10;CFD;C1QA;HLA-DRB5;FPR1;HLA-DMA;HLA-DMB;HL...
# 10  CD274;HLA-DRB5;CD2;CLDN10;HLA-DMA;HLA-DMB;CD8B...
# 11  IL10;JUN;HLA-DRB5;TNF;HLA-DMA;HLA-DMB;IL1B;HLA...
# 12  IL10;HLA-DMA;HLA-DRB5;HLA-DMB;HLA-DPB1;CXCR4;H...
# 13  HLA-DRB5;ACTG1;CASP9;HLA-DMA;HLA-DMB;HLA-DPB1;...
# 14  IL10;C1QA;HLA-DRB5;HIST1H4L;ACTN1;TNF;HLA-DMA;...
# 15  IL10;HLA-DMA;HLA-DRB5;HLA-DMB;HLA-DPB1;GZMB;HL...
# 16  IL10;HLA-DRB5;HSPA6;TNF;PIK3R5;NFKBIA;CASP9;HL...
# 17  CD74;HLA-DRB5;JUN;CFP;TNF;NFKBIA;SOCS3;HLA-DMA...
# 18  IL10;CD74;HLA-DRB5;FCER1G;RIPK2;TNF;CTSS;CASP9...
# 19  JUN;GADD45B;BCL2A1;GZMB;TNFRSF10A;CTSW;TNF;CTS...
# 20  HLA-DRB5;NCF2;TUBB;MPO;CTSS;ACTG1;TUBA1B;HLA-D...
# 21  IL10;C1QA;JUN;CCL3L1;TNF;CD3D;PIK3R5;NFKBIA;GN...
# 22        IL10;GYPA;KLRB1;CD81;GYPB;HGF;IL1B;HBA1;TNF
# 23  CD79B;NFKBIA;CD79A;JUN;CD81;AKT3;BLNK;RAC3;NFA...
# 24  TKTL1;ARG2;TPI1;PKM;PSAT1;GPT;PHGDH;ENO1;ALDH7...
# 25  RANBP1;HLA-DRB5;JUN;CDKN1A;NFATC2;CD3D;TNF;PIK...
# 26  LDHB;LDHA;TPI1;PKM;ALDH2;ENO1;BPGM;ALDH7A1;GAP...
# 27  IL10;HLA-DRB5;JUN;CDKN1A;HSPA6;PIK3R5;NFKBIA;C...
# 28  NFKBIA;BCL2A1;GADD45B;IL1B;CCL4;BLNK;LTB;CD14;...
# 29                 CD79A;CD8B;IGLL1;BLNK;CD3D;ADA;UNG
# 30      CASP9;JUN;APC;MYC;AKT3;LEF1;RAC3;APPL1;PIK3R5
# 31  PLA2G16;HPGDS;PLA2G1B;EPHX2;AKR1C3;PLA2G4A;PTG...
# 32            ALAS2;PSAT1;AMT;PHGDH;BPGM;ALDH7A1;GNMT
# 33  JUN;CSF1;NCF2;SIRPG;NFATC2;TNF;OSCAR;PIK3R5;NF...
# 34       CASP9;NFKBIA;IL1B;HSPA6;CD14;CXCL3;CXCL2;TNF
# 35  NFKBIA;SOCS3;JUN;CSF1;IL1B;CCL5;AKT3;CXCL3;PTG...
# 36  IL10;SERPINB10;ARG2;SERPINB1;GNA15;ACTN1;IL1B;...
# 37  CASP9;SH2D2A;AKT3;RAC3;PLA2G4A;NFATC2;PTGS2;PI...
# 38     IL10;C1QA;JUN;IL1B;IRF8;SERPING1;NOD1;CD14;TNF
# 39               ARG2;OAT;ALDH2;CKB;ALDH7A1;SRM;AGMAT
# 40  NFKBIA;IL10;JUN;CD8B;AKT3;NFATC2;CD247;TNF;CD3...
# 41  FCER1G;SH2D1A;NFATC2;GZMB;TNFRSF10A;TNF;PIK3R5...
# 42  NFKBIA;JUN;CCL3L1;IL1B;CCL5;AKT3;CCL4;CCL3;CD1...
# 43     FCER1G;AKT3;FCER1A;RAC3;PLA2G4A;TNF;LAT;PIK3R5
# 44                       C12ORF5;TPI1;MPI;AKR1B1;PFKP
# 45              NFKBIA;RIPK2;IL1B;CCL5;NOD1;CXCL2;TNF
# 46   JUN;CCL3L1;IL1B;CCL4;CCL3;CD14;CXCL3;CXCL2;ACTG1

# %%
len(top_genes)
# Out:
# 928
